# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/leagues"

headers = {
    "X-RapidAPI-Key": "d84cd3a986msh99290296f083073p12e132jsnfac9c2bd37bb",
    "X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

params = {'team': '33', 'season': '2022'}

response = requests.get(url, headers=headers).json()['response']

# %%
ecuadorLeagues = []

for x in response:
    if x['country']['name'] == 'Ecuador':
        ecuadorLeagues.append(x)

# %%
ecuadorLeagues[3]
# Out:
# {'league': {'id': 917,
#   'name': 'Copa Ecuador',
#   'type': 'Cup',
#   'logo': 'https://media-1.api-sports.io/football/leagues/917.png'},
#  'country': {'name': 'Ecuador',
#   'code': 'EC',
#   'flag': 'https://media-1.api-sports.io/flags/ec.svg'},
#  'seasons': [{'year': 2022,
#    'start': '2022-05-07',
#    'end': '2022-11-09',
#    'current': True,
#    'coverage': {'fixtures': {'events': True,
#      'lineups': False,
#      'statistics_fixtures': False,
#      'statistics_players': False},
#     'standings': False,
#     'players': False,
#     'top_scorers': False,
#     'top_assists': False,
#     'top_cards': False,
#     'injuries': False,
#     'predictions': True,
#     'odds': False}}]}

# %%
response[0]
# Out:
# {'league': {'id': 4,
#   'name': 'Euro Championship',
#   'type': 'Cup',
#   'logo': 'https://media-3.api-sports.io/football/leagues/4.png'},
#  'country': {'name': 'World', 'code': None, 'flag': None},
#  'seasons': [{'year': 2008,
#    'start': '2008-06-07',
#    'end': '2008-06-29',
#    'current': False,
#    'coverage': {'fixtures': {'events': True,
#      'lineups': True,
#      'statistics_fixtures': False,
#      'statistics_players': False},
#     'standings': False,
#     'players': False,
#     'top_scorers': False,
#     'top_assists': False,
#     'top_cards': False,
#     'injuries': False,
#     'predictions': True,
#     'odds': False}},
#   {'year': 2012,
#    'start': '2012-06-08',
#    'end': '2012-07-01',
#    'current': False,
#    'coverage': {'fixtures': {'events': True,
#      'lineups': True,
#      'statistics_fixtures': False,
#      'statistics_players': False},
#     'standings': False,
#     'players': False,
#     'top_scorers': False,
# ...

# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/leagues"

headers = {
    "X-RapidAPI-Key": "d84cd3a986msh99290296f083073p12e132jsnfac9c2bd37bb",
    "X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

#params = {'team': '33', 'season': '2022'}

response = requests.get(url, headers=headers).json()['response']

leagues = []

for x in response:
    data = {'leagueName': x['name'],
            'leagueId': x['id'],
            'leagueCountry': x['country'],
            'numSeasons': len(x['seasons']),
            'mostRecentSeason': x['seasons'][0]} 
    leagues.append(data)

print ('hello')

print ('hola')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 16>()
#      14 leagues = []
#      16 for x in response:
# ---> 17     data = {'leagueName': x['name'],
#      18             'leagueId': x['id'],
#      19             'leagueCountry': x['country'],
#      20             'numSeasons': len(x['seasons']),
#      21             'mostRecentSeason': x['seasons'][0]}
#      22     leagues.append(data)
#      24 print ('hello')
#
# KeyError: 'name'

# %%
leagues
# Out:
# []

# %%
response['response'][0]['statistics']
# Out:
# [{'team': {'id': 33,
#    'name': 'Manchester United',
#    'logo': 'https://media-2.api-sports.io/football/teams/33.png'},
#   'league': {'id': 39,
#    'name': 'Premier League',
#    'country': 'England',
#    'logo': 'https://media-1.api-sports.io/football/leagues/39.png',
#    'flag': 'https://media-2.api-sports.io/flags/gb.svg',
#    'season': 2022},
#   'games': {'appearences': 38,
#    'lineups': 38,
#    'minutes': 3420,
#    'number': None,
#    'position': 'Goalkeeper',
#    'rating': '6.934210',
#    'captain': False},
#   'substitutes': {'in': 0, 'out': 0, 'bench': 0},
#   'shots': {'total': None, 'on': None},
#   'goals': {'total': 0, 'conceded': 43, 'assists': None, 'saves': 101},
#   'passes': {'total': 1083, 'key': 1, 'accuracy': 19},
#   'tackles': {'total': None, 'blocks': None, 'interceptions': 1},
#   'duels': {'total': 12, 'won': 10},
#   'dribbles': {'attempts': None, 'success': None, 'past': None},
#   'fouls': {'drawn': 5, 'committed': None},
# ...

# %%
#response

# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/leagues"

headers = {
    "X-RapidAPI-Key": "d84cd3a986msh99290296f083073p12e132jsnfac9c2bd37bb",
    "X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers).json()

##print(response.json())

# %%
response
# Out:
# {'get': 'leagues',
#  'parameters': [],
#  'errors': [],
#  'results': 1001,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'league': {'id': 4,
#     'name': 'Euro Championship',
#     'type': 'Cup',
#     'logo': 'https://media-3.api-sports.io/football/leagues/4.png'},
#    'country': {'name': 'World', 'code': None, 'flag': None},
#    'seasons': [{'year': 2008,
#      'start': '2008-06-07',
#      'end': '2008-06-29',
#      'current': False,
#      'coverage': {'fixtures': {'events': True,
#        'lineups': True,
#        'statistics_fixtures': False,
#        'statistics_players': False},
#       'standings': False,
#       'players': False,
#       'top_scorers': False,
#       'top_assists': False,
#       'top_cards': False,
#       'injuries': False,
#       'predictions': True,
#       'odds': False}},
#     {'year': 2012,
#      'start': '2012-06-08',
#      'end': '2012-07-01',
#      'current': False,
#      'coverage': {'fixtures': {'events': True,
# ...
